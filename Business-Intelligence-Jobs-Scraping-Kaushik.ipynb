# %% [markdown]
# ## Scraping Data Scientist jobs from Seek.com.au using Beautiful Soup

# %%
# Importing libraries
import re
import pandas as pd
from scrapy.selector import Selector
from scrapy.http import HtmlResponse
import requests
from bs4 import BeautifulSoup
import json
from time import sleep

# %%
# Choosing two salary ranges for each job, which are the equivalent of Low and High
salary_ranges = ['50000-80000', '80000-120000', '120000-150000']

# Dictionary to store all the web links
job_urls = {}

for salary_range in salary_ranges:
    job_urls[salary_range]=[]
    for page in range(1,40):
        # iterate through the first 40 pages of jobs
        r = requests.get("https://www.seek.com.au/business-intelligence-analyst-jobs/in-All-Sydney-NSW?page={0}&salaryrange={1}&salarytype=annual".format(str(page),salary_range))

        # turn into a BeautifulSoup object
        soup = BeautifulSoup(r.text, 'lxml')

        # find urls on page
        url = soup.find_all(attrs={'data-automation':"jobTitle"})
        /
        if url != []: 
            job_urls[salary_range].extend(url)

# %%
df_1 = pd.DataFrame()
df_1['Link'] = job_urls['50000-80000']
df_1['Salary Range'] = '50000-80000'

# %%
df_1.head()
# Out:
#                                                 Link Salary Range
# 0  <a class="_2iNL7wI" data-automation="jobTitle"...  50000-80000
# 1  <a class="_2iNL7wI" data-automation="jobTitle"...  50000-80000
# 2  <a class="_2iNL7wI" data-automation="jobTitle"...  50000-80000
# 3  <a class="_2iNL7wI" data-automation="jobTitle"...  50000-80000
# 4  <a class="_2iNL7wI" data-automation="jobTitle"...  50000-80000

# %%
df_2 = pd.DataFrame()
df_2['Link'] = job_urls['80000-120000']
df_2['Salary Range'] = '80000-120000'

# %%
df_3 = pd.DataFrame()
df_3['Link'] = job_urls['120000-150000']
df_3['Salary Range'] = '120000-150000'

# %%
url_pd = df_1.append(df_2).append(df_3)

# %%
url_pd.tail()
# Out:
#                                                   Link   Salary Range
# 335  <a class="_2iNL7wI" data-automation="jobTitle"...  120000-150000
# 336  <a class="_2iNL7wI" data-automation="jobTitle"...  120000-150000
# 337  <a class="_2iNL7wI" data-automation="jobTitle"...  120000-150000
# 338  <a class="_2iNL7wI" data-automation="jobTitle"...  120000-150000
# 339  <a class="_2iNL7wI" data-automation="jobTitle"...  120000-150000

# %%
url_pd['Link_1'] = ['https://www.seek.com.au' + re.search('(\/job\/[0-9]{8})',i.attrs['href']).group(0) for i in url_pd['Link']]

# %%
url_pd.head()
# Out:
#                                                 Link Salary Range  \
# 0  <a class="_2iNL7wI" data-automation="jobTitle"...  50000-80000
# 1  <a class="_2iNL7wI" data-automation="jobTitle"...  50000-80000
# 2  <a class="_2iNL7wI" data-automation="jobTitle"...  50000-80000
# 3  <a class="_2iNL7wI" data-automation="jobTitle"...  50000-80000
# 4  <a class="_2iNL7wI" data-automation="jobTitle"...  50000-80000
#
#                                  Link_1
# 0  https://www.seek.com.au/job/40099652
# 1  https://www.seek.com.au/job/40089444
# 2  https://www.seek.com.au/job/40001520
# 3  https://www.seek.com.au/job/40083452
# 4  https://www.seek.com.au/job/40099652

# %%
url_pd['Title'] = [i.text for i in url_pd['Link']]

# %%
url_pd = url_pd.drop('Link',axis='columns')

# %%
url_pd.head()
# Out:
#   Salary Range                                Link_1  \
# 0  50000-80000  https://www.seek.com.au/job/40099652
# 1  50000-80000  https://www.seek.com.au/job/40089444
# 2  50000-80000  https://www.seek.com.au/job/40001520
# 3  50000-80000  https://www.seek.com.au/job/40083452
# 4  50000-80000  https://www.seek.com.au/job/40099652
#
#                                                Title
# 0  Business Intelligence Analyst - Australia's #1...
# 1  Experienced Actuarial and Analytics Consultant...
# 2  Business Analysis/Business Intelligence (BA/BI...
# 3            Business Intelligence Reporting Analyst
# 4  Business Intelligence Analyst - Australia's #1...

# %%
columns = ['Salary Range', 'Link', "Title"]
url_pd.columns=columns

# %%
url_pd.head()
# Out:
#   Salary Range                                  Link  \
# 0  50000-80000  https://www.seek.com.au/job/40099652
# 1  50000-80000  https://www.seek.com.au/job/40089444
# 2  50000-80000  https://www.seek.com.au/job/40001520
# 3  50000-80000  https://www.seek.com.au/job/40083452
# 4  50000-80000  https://www.seek.com.au/job/40099652
#
#                                                Title
# 0  Business Intelligence Analyst - Australia's #1...
# 1  Experienced Actuarial and Analytics Consultant...
# 2  Business Analysis/Business Intelligence (BA/BI...
# 3            Business Intelligence Reporting Analyst
# 4  Business Intelligence Analyst - Australia's #1...

# %%
#for stemming
import re

def replace(string, substitutions):

    substrings = sorted(substitutions, key=len, reverse=True)
    regex = re.compile('|'.join(map(re.escape, substrings)))
    return regex.sub(lambda match: substitutions[match.group(0)], string)

# %%
job_listing_date=[]
job_expiry_date=[]
job_title = []
job_teaser=[]
job_advertiser=[]
job_area=[]
job_worktype=[]
job_classification=[]
job_salary=[]
job_salary_type=[]
job_description_details=[]
job_description_strong = []
job_location =[]

for index, job in enumerate(url_pd['Link']):
    # iterate through all the urls
    try:
        r = requests.get(job)
    except:
        time.sleep(5)
    
    # turn into a BeautifulSoup object
    soup = BeautifulSoup(r.text, 'lxml')
    
    # find job descriptions
    jd_data = soup.find_all(attrs={'data-automation':'server-state'})[0]
    jd_raw= jd_data.text[3:].split('\n  ')[1][25:][:-1]
    jd_dict = json.loads(jd_raw)
    jd_dashboard = jd_dict['jobdetails']['result']
    
    if jd_dashboard['listingDate']:
        job_listing_date.append(jd_dashboard['listingDate'])
    else:
        job_listing_date.append('N/A')
        
    if jd_dashboard['expiryDate']:
        job_expiry_date.append(jd_dashboard['expiryDate'])
    else:
        job_expiry_date.append('N/A')
        
    if jd_dashboard['title']:
        job_title.append(jd_dashboard['title'])
    else:
        job_title.append('N/A')
        
    if jd_dashboard['teaser']:
        job_teaser.append(jd_dashboard['teaser'])
    else:
        job_teaser.append('N/A')
        
    if jd_dashboard['advertiser']['description']:
        job_advertiser.append(jd_dashboard['advertiser']['description'])
    else:
        job_advertiser.append('N/A')
        
    if jd_dashboard['locationHierarchy']['area']:
        job_area.append(jd_dashboard['locationHierarchy']['area'])
    else:
        job_area.append('N/A')
        
    if jd_dashboard['workType']:
        job_worktype.append(jd_dashboard['workType'])
    else:
        job_worktype.append('N/A')
        
    if jd_dashboard['classification']['description']:
        job_classification.append(jd_dashboard['classification']['description'])
    else:
        job_classification.append('N/A')
        
    if jd_dashboard['salary']:
        job_salary.append(jd_dashboard['salary'])
    else:
        job_salary.append('N/A')
        
    if jd_dashboard['salaryType']:
        job_salary_type.append(jd_dashboard['salaryType'])
    else:
        job_salary_type.append('N/A')
        
    if jd_dashboard['locationHierarchy']['city']:
        job_location.append(jd_dashboard['locationHierarchy']['city'])
    else:
        job_location.append('N/A')
        
    
    jd_detail = soup.find(attrs={'data-automation':'mobileTemplate'})
    job_description_details.append(jd_detail)

# %%
url_pd['Listing Date'] = job_listing_date
url_pd['Expiry Date'] =job_expiry_date
url_pd['Job Title']=job_title
url_pd['Job Teaser']=job_teaser
url_pd['Advertiser'] = job_advertiser
url_pd['Area'] = job_area
url_pd['Work Type'] = job_worktype
url_pd['Classification'] = job_classification
url_pd['Salary'] = job_salary
url_pd['Salary Type'] = job_salary_type
url_pd['JD'] = job_description_details
url_pd['Location'] =job_location

# %%
# Check the type for 'JD' column and start cleaning
type(job_description_details)
# Out:
# list

# %%
job_description_clean=[]
job_description_strong = []
for i in range(0,len(url_pd['JD'])):
    try:
        strong_word = job_description_details[i].find_all('strong')
        strong_word_list = [u.get_text(strip=True) for u in strong_word if strong_word != False]
        job_description_strong.append(strong_word_list)

        string = job_description_details[i].get_text()
        repla = {u'\xa0':'  ',u'\xe2\x80\x9d':'  ', u'\n':'  '}
        job_description_clean.append(replace(string,repla))
    except:
        job_description_strong.append('N/A')
        job_description_clean.append('N/A')

# %%
url_pd['Job Description'] = job_description_clean
url_pd['Strong Words'] = job_description_strong

# %%
business_intelligence_jobs = url_pd.copy()

# %%
business_intelligence_jobs.to_csv('business_intelligence_jobs.csv')

# %%
business_intelligence_jobs.tail(10)
# Out:
#       Salary Range                                  Link  \
# 330  120000-150000  https://www.seek.com.au/job/40097109
# 331  120000-150000  https://www.seek.com.au/job/40147122
# 332  120000-150000  https://www.seek.com.au/job/40120897
# 333  120000-150000  https://www.seek.com.au/job/40063017
# 334  120000-150000  https://www.seek.com.au/job/40063931
# 335  120000-150000  https://www.seek.com.au/job/40158236
# 336  120000-150000  https://www.seek.com.au/job/40098049
# 337  120000-150000  https://www.seek.com.au/job/40096110
# 338  120000-150000  https://www.seek.com.au/job/40249953
# 339  120000-150000  https://www.seek.com.au/job/40125574
#
#                                                  Title  \
# 330                          Consumer Insights Analyst
# 331            Senior Insights Analyst - SAS, R or SQL
# 332           Senior Analyst, Financial Risk Analytics
# 333                          Consumer Insights Analyst
# 334                                       FP&A Analyst
# 335      AUEXP173061- IAM Technical Support Specialist
# 336  Power System Engineer/Analyst/Software Develop...
# 337                          Superannuation Consultant
# 338  Bid and Proposal Manager - Cyber Security Serv...
# 339  Marketing Executive - Conversions & Expansion ...
#
#                  Listing Date               Expiry Date  \
# 330  2019-10-04T04:50:24.000Z  2019-11-03T12:59:59.000Z
# 331  2019-10-11T06:20:38.000Z  2019-11-10T12:59:59.000Z
# 332  2019-10-08T23:37:27.000Z  2019-11-07T23:37:26.000Z
# 333  2019-10-01T00:26:15.000Z  2019-10-31T12:59:59.000Z
# 334  2019-10-01T01:15:42.000Z  2019-10-31T12:59:59.000Z
# 335  2019-10-14T04:47:41.000Z  2019-11-13T12:59:59.000Z
# 336  2019-10-04T05:39:42.000Z  2019-11-03T05:39:41.000Z
# 337  2019-10-04T03:54:31.000Z  2019-11-03T12:59:59.000Z
# 338  2019-10-25T05:28:00.000Z  2019-11-24T05:27:58.000Z
# 339  2019-10-09T04:48:58.000Z  2019-11-08T04:48:56.000Z
#
#                                              Job Title  \
# 330                          Consumer Insights Analyst
# 331            Senior Insights Analyst - SAS, R or SQL
# 332           Senior Analyst, Financial Risk Analytics
# 333                          Consumer Insights Analyst
# 334                                       FP&A Analyst
# 335      AUEXP173061- IAM Technical Support Specialist
# 336  Power System Engineer/Analyst/Software Develop...
# 337                          Superannuation Consultant
# 338  Bid and Proposal Manager - Cyber Security Serv...
# 339  Marketing Executive - Conversions & Expansion ...
#
#                                             Job Teaser  \
# 330  Exciting Commercial role business partnering w...
# 331  We are currently seeking a Senior Insights Ana...
# 332  This pivotal role will see you actively facili...
# 333  Exciting Commercial role business partnering w...
# 334  An exciting opportunity has arisen for an expe...
# 335  Experienced identity and access management pro...
# 336  AEMO are responsible for operating Australia’s...
# 337  You will wear 2 hats in this role - providing ...
# 338  New role for proven bid and proposal manager t...
# 339  Growing Hormone Clinic looking for Marketing S...
#
#                                    Advertiser  \
# 330                    Talent Web Recruitment
# 331             Bluefin Resources Pty Limited
# 332                                       QBE
# 333                    Talent Web Recruitment
# 334                                   Talenza
# 335                                  Deloitte
# 336  Australian Energy Market Operator (AEMO)
# 337                          B & K Consulting
# 338                  Enosys Solutions Pty Ltd
# 339                      The Lucy Rose Clinic
#
#                                   Area  Work Type  \
# 330     North Shore & Northern Beaches  Full Time
# 331  CBD, Inner West & Eastern Suburbs  Full Time
# 332  CBD, Inner West & Eastern Suburbs  Full Time
# 333     North Shore & Northern Beaches  Full Time
# 334  CBD, Inner West & Eastern Suburbs  Full Time
# 335  CBD, Inner West & Eastern Suburbs  Full Time
# 336  CBD, Inner West & Eastern Suburbs  Full Time
# 337  CBD, Inner West & Eastern Suburbs  Full Time
# 338  CBD, Inner West & Eastern Suburbs  Full Time
# 339  CBD, Inner West & Eastern Suburbs  Full Time
#
#                              Classification  \
# 330              Marketing & Communications
# 331            Banking & Financial Services
# 332            Banking & Financial Services
# 333                   Consulting & Strategy
# 334            Banking & Financial Services
# 335  Information & Communication Technology
# 336              Mining, Resources & Energy
# 337              Insurance & Superannuation
# 338  Information & Communication Technology
# 339              Marketing & Communications
#
#                                    Salary       Salary Type  \
# 330          $110000.00 - $120450.00 p.a.     AnnualPackage
# 331                                   N/A     AnnualPackage
# 332                                   N/A     AnnualPackage
# 333          $110000.00 - $120450.00 p.a.     AnnualPackage
# 334            $100k - $120k p.a. + Super     AnnualPackage
# 335                                   N/A     AnnualPackage
# 336                                   N/A  AnnualCommission
# 337  $120k - $140k p.a. + Superannuation      AnnualPackage
# 338                                   N/A  AnnualCommission
# 339                                   N/A     AnnualPackage
#
#                                                     JD Location  \
# 330  <div class="_2e4Pi2B" data-automation="mobileT...   Sydney
# 331  <div class="_2e4Pi2B" data-automation="mobileT...   Sydney
# 332  <div class="_2e4Pi2B" data-automation="mobileT...   Sydney
# 333  <div class="_2e4Pi2B" data-automation="mobileT...   Sydney
# 334  <div class="_2e4Pi2B" data-automation="mobileT...   Sydney
# 335  <div class="_2e4Pi2B" data-automation="mobileT...   Sydney
# 336  <div class="_2e4Pi2B" data-automation="mobileT...   Sydney
# 337  <div class="_2e4Pi2B" data-automation="mobileT...   Sydney
# 338  <div class="_2e4Pi2B" data-automation="mobileT...   Sydney
# 339  <div class="_2e4Pi2B" data-automation="mobileT...   Sydney
#
#                                        Job Description  \
# 330  North SydneyInfluence Marketing Campaigns with...
# 331  We are currently seeking Insight Analysts & Se...
# 332  Financial Risk Analytics| Investment Risk | Gl...
# 333  North SydneyInfluence Marketing Campaigns with...
# 334  The role will assist in monitoring of division...
# 335  Risk Advisory - Cyber Intelligence Centre - IA...
# 336  About the Role: Our Operations team is looking...
# 337  Our client is a leading provider of Superannua...
# 338  Only Australian Citizens or Permanent Resident...
# 339  The Lucy Rose Clinic is a leading integrative ...
#
#                                           Strong Words
# 330                     [COMPANY, ROLE, Requirements:]
# 331                                                 []
# 332  [Senior Analyst, Financial Risk Analytics, Abo...
# 333                     [COMPANY, ROLE, Requirements:]
# 334         [Key Responsibilities:, Key Requirements:]
# 335                                                 []
# 336  [About the Role, Key accountabilities:, Requir...
# 337                                                 []
# 338  [Only Australian Citizens or Permanent Residen...
# 339                                                 []
